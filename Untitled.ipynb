# %%
import json
import pandas as pd
import boto3
from datetime import datetime

pd.set_option('display.max_columns', None)


# Function to list each tech language skill in JSON as new column with key as column label and value as cell in row
def expand_tech_self_score(df):
    # Check 'tech_self_score' column exists in our pre-created data frames and that it contains dictionaries
    if 'tech_self_score' in df and all(isinstance(item, dict) for item in df['tech_self_score']):
        # Split dictionary into separate columns
        tech_self_score_df = pd.DataFrame(df['tech_self_score'].tolist())

        # Add the new columns to pre-existing data frame (now languages are last columns)
        df = pd.concat([df, tech_self_score_df], axis=1)

        # Drop the original 'tech_self_score' column since it has been replaced will the new columns
        df.drop(columns=['tech_self_score'], inplace=True)
    return df


def expand_strength_weakness(df):
    # Check strength and weakness columns exits in the pre-existing data frame
    if 'strengths' in df and all(isinstance(item, list) for item in df['strengths']):
        # Create separate columns for each item in list
        strength_df = pd.DataFrame(df['strengths'].tolist(),
                                   columns=[f'strengths {i + 1}' for i in range(len(df['strengths'][0]))])

        # Add the new columns to the pre-existing data frame
        df = pd.concat([df, strength_df], axis=1)

        # Drop original strength column
        df.drop(columns=['strengths'], inplace=True)

    if 'weaknesses' in df and all(isinstance(item, list) for item in df['weaknesses']):
        # Create separate columns for each listy item
        weakness_df = pd.DataFrame(df['weaknesses'].tolist(),
                                   columns=[f'weaknesses {i + 1}' for i in range(len(df['weaknesses'][0]))])

        # Add new weakness columns to ore-existing data frame
        df = pd.concat([df, weakness_df], axis=1)

        # Droporiginal 'weakness' column
        df.drop(columns=['weaknesses'], inplace=True)
    return df

def split_name_column(df):
    if 'name' in df.columns:
        df[['first_name', 'last_name']] = df['name'].str.split(n=1, expand=True)
        df.drop(columns=['name'], inplace=True)
    return df

# MAIN FUNCTION TO EXTRACT AND CONVERT JSON FILE TO DATA FRAME
def json_df():
    s3_client = boto3.client('s3')
    s3_resource = boto3.resource('s3')

    bucket_name = 'data-249-final-project'
    directory_prefix = 'Talent/'
    df_array = []

    try:
        # Use paginator to avoid only returning first 1000 objects
        paginator = s3_client.get_paginator('list_objects')
        for page in paginator.paginate(Bucket=bucket_name, Prefix=directory_prefix):
            if 'Contents' in page:
                json_objects = [obj for obj in page['Contents'] if obj['Key'].endswith('.json')]
                for json_object in json_objects:
                    response = s3_resource.Object(bucket_name, json_object['Key']).get()
                    json_content = response['Body'].read()

                    data = json.loads(json_content)

                    # Create DF from JSON data
                    if isinstance(data, list):  # Check if the JSON data is a list of dictionaries
                        df = pd.DataFrame(data)
                        df_array.append(df)
                    elif isinstance(data, dict):  # Check if the JSON data is a single dictionary
                        df = pd.DataFrame([data])
                        df_array.append(df)
                    else:
                        print(f"Unsupported JSON format in '{json_object['Key']}'")

    except Exception as e:
        print(f"Error: {e}")

    return df_array


def convert_yes_no_to_binary(df):
    for column in df.columns:
        if df[column].dtype == 'object':
            df[column] = df[column].apply(lambda x: 1 if x.lower() == 'yes' else (0 if x.lower() == 'no' else x))
    return df

# This function makes all the transformation functions take effect on the original extracted data frame so the new,
# transformed dataframe is the processed one
def process_example_dfs(example_dfs):
    processed_dfs = []
    for df in example_dfs:
        df = expand_tech_self_score(df)
        df = expand_strength_weakness(df)
        df = split_name_column(df)
        df = convert_yes_no_to_binary(df)
        processed_dfs.append(df)
    return processed_dfs


if __name__ == "__main__":
    example_dfs = json_df()
    print(process_example_dfs(example_dfs))
# Out:
# [         date  self_development  geo_flex  financial_support_self result  \
# 0  22/08/2019                 1         1                       1   Pass
#
#   course_interest  C#  Java  R  JavaScript strengths 1 weaknesses 1  \
# 0        Business   6     5  2           2    Charisma   Distracted
#
#   weaknesses 2 weaknesses 3 first_name last_name
# 0    Impulsive  Introverted  Stillmann   Castano  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  01/08/2019                 0         1                       1   Fail
#
#   course_interest  Python  C#  Java  C++ strengths 1 strengths 2  \
# 0            Data       1   4     2    4     Patient     Curious
#
#        strengths 3 weaknesses 1 weaknesses 2 weaknesses 3 first_name last_name
# 0  Problem Solving  Overbearing       Chatty  Indifferent     Hilary  Willmore  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  22/08/2019                 1         1                       1   Pass
#
#   course_interest  Ruby  C++ strengths 1  strengths 2 strengths 3  \
# 0        Business     4    4   Courteous  Independent     Patient
#
#   weaknesses 1 weaknesses 2 weaknesses 3 first_name last_name
# 0  Introverted    Impulsive      Anxious      Efrem   Whipple  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  28/08/2019                 1         1                       1   Pass
#
#   course_interest  Java  SPSS strengths 1   weaknesses 1 weaknesses 2  \
# 0            Data     3     4  Passionate  Perfectionist    Sensitive
#
#   first_name last_name
# 0      Sydel     Fenne  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  07/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  Java  Ruby  R  PHP  C++ strengths 1 weaknesses 1  \
# 0     Engineering       3     4     1  2    2    3   Versatile  Controlling
#
#     weaknesses 2 weaknesses 3 first_name last_name
# 0  Perfectionist       Chatty     Michel  Lebarree  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  14/08/2019                 1         1                       0   Fail
#
#   course_interest  C#  Java  PHP strengths 1 strengths 2 weaknesses 1  \
# 0        Business   3     1    4   Versatile    Rational     Immature
#
#   first_name last_name
# 0     Cooper  Ingraham  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  22/08/2019                 1         1                       1   Fail
#
#   course_interest  SPSS  PHP  C++    strengths 1 weaknesses 1  weaknesses 2  \
# 0        Business     3    3    2  Collaboration    Impatient  Conventional
#
#     weaknesses 3 first_name last_name
# 0  Undisciplined       Bird  Le Count  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  01/08/2019                 0         1                       1   Fail
#
#   course_interest  Ruby  R  SPSS  JavaScript strengths 1  strengths 2  \
# 0        Business     2  5     1           1   Ambitious  Independent
#
#   strengths 3  weaknesses 1 weaknesses 2 first_name last_name
# 0  Passionate  Conventional      Passive       Orly    Lorens  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  29/08/2019                 1         1                       1   Fail
#
#   course_interest  Python  Ruby  JavaScript strengths 1 strengths 2  \
# 0            Data       8     2           2    Reliable  Passionate
#
#   weaknesses 1 first_name last_name
# 0   Intolerant     Hannah    Messum  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  21/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  C#  C++  JavaScript strengths 1 strengths 2  \
# 0            Data       3   2    5           1    Altruism     Empathy
#
#        strengths 3 weaknesses 1 weaknesses 2 first_name  last_name
# 0  Problem Solving      Chaotic      Selfish      Gavin  Lambregts  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  08/08/2019                 1         1                       1   Fail
#
#   course_interest  PHP  JavaScript strengths 1 strengths 2   weaknesses 1  \
# 0        Business    3           4   Listening  Passionate  Perfectionist
#
#   weaknesses 2 weaknesses 3 first_name last_name
# 0     Immature      Passive      Letta   Halston  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  08/08/2019                 1         1                       0   Fail
#
#   course_interest  Python  Ruby  JavaScript   strengths 1 strengths 2  \
# 0     Engineering       3     4           2  Organisation  Passionate
#
#   strengths 3  weaknesses 1 weaknesses 2 weaknesses 3 first_name last_name
# 0   Versatile  Conventional    Sensitive  Introverted    Rivalee  Eagleton  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  15/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  Ruby  R  C++ strengths 1 strengths 2 strengths 3  \
# 0            Data       4     5  7    1     Curious   Ambitious  Consistent
#
#   weaknesses 1 first_name last_name
# 0    Sensitive       Neda   Marmyon  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  29/08/2019                 1         0                       1   Fail
#
#   course_interest  PHP strengths 1 strengths 2 weaknesses 1 weaknesses 2  \
# 0        Business    2   Versatile   Ambitious         Slow  Overbearing
#
#    weaknesses 3 first_name last_name
# 0  Conventional      Kermy     Caves  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  07/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  C#  Java strengths 1 strengths 2   weaknesses 1  \
# 0     Engineering       4   3     3  Passionate   Versatile  Undisciplined
#
#   first_name last_name
# 0     Edithe  Dimitrov  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  06/08/2019                 1         1                       0   Fail
#
#   course_interest  Python  C#  Ruby  JavaScript strengths 1  strengths 2  \
# 0            Data       4   3     3           3   Efficient  Independent
#
#   weaknesses 1 weaknesses 2 weaknesses 3 first_name last_name
# 0  Indifferent    Sensitive  Introverted     Aubert  Cicerone  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  14/08/2019                 1         0                       0   Fail
#
#   course_interest  Python  C#  SPSS  PHP      strengths 1 strengths 2  \
# 0            Data       3   3     2    1  Problem Solving    Altruism
#
#   weaknesses 1 first_name last_name
# 0  Indifferent    Erastus  Mcelrath  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  28/08/2019                 0         1                       1   Fail
#
#   course_interest  Python  C#  Ruby  JavaScript  strengths 1 weaknesses 1  \
# 0            Data       2   7     4           2  Independent  Controlling
#
#   weaknesses 2 first_name last_name
# 0    Impulsive      Edgar  Annesley  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  07/08/2019                 1         1                       1   Pass
#
#   course_interest      strengths 1 strengths 2 strengths 3   weaknesses 1  \
# 0     Engineering  Problem Solving   Efficient     Patient  Undisciplined
#
#   first_name last_name
# 0    Haslett     Steet  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  08/08/2019                 1         1                       0   Fail
#
#   course_interest  C++ strengths 1 weaknesses 1 first_name  last_name
# 0     Engineering    1  Determined      Anxious     Kirbee  Clementet  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  21/08/2019                 1         1                       1   Pass
#
#   course_interest  C#  Java strengths 1  strengths 2 weaknesses 1  \
# 0        Business   4     5   Composure  Independent    Impulsive
#
#   weaknesses 2 weaknesses 3  first_name last_name
# 0  Competitive  Controlling  Marcellina      Ping  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  14/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  C#  Ruby  C++  strengths 1 strengths 2  \
# 0            Data       2   1     2    3  Competitive     Empathy
#
#   weaknesses 1 first_name last_name
# 0    Impulsive     Violet  Luscombe  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  06/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  C#  R  SPSS      strengths 1 weaknesses 1  \
# 0            Data       1   3  2     2  Problem Solving  Overbearing
#
#   weaknesses 2 first_name last_name
# 0    Impatient    Phillis     Wabey  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  29/08/2019                 1         1                       1   Pass
#
#   course_interest  Ruby  R  SPSS  C++  JavaScript strengths 1  \
# 0     Engineering     6  4     4    2           3   Composure
#
#        strengths 2 strengths 3 weaknesses 1 weaknesses 2 first_name last_name
# 0  Problem Solving   Efficient    Impatient     Critical    Maurice    Yakhin  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  13/08/2019                 0         1                       1   Fail
#
#   course_interest strengths 1      strengths 2 strengths 3 weaknesses 1  \
# 0        Business  Determined  Problem Solving     Patient   Indecisive
#
#     weaknesses 2 first_name last_name
# 0  Undisciplined     Wesley  Tolerton  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  15/08/2019                 1         1                       1   Pass
#
#   course_interest  R  SPSS    strengths 1 strengths 2 weaknesses 1  \
# 0     Engineering  4     2  Perfectionism    Charisma  Overbearing
#
#    weaknesses 2 weaknesses 3 first_name last_name
# 0  Conventional     Immature  Brittaney   Roughey  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  15/08/2019                 1         1                       1   Pass
#
#   course_interest  C#  R strengths 1 weaknesses 1 first_name last_name
# 0     Engineering   1  2    Reliable      Passive      Saree     Daens  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  08/08/2019                 1         1                       1   Pass
#
#   course_interest  C#  Java  Ruby  R  PHP  JavaScript strengths 1  \
# 0     Engineering   1     3     2  1    2           2  Passionate
#
#   weaknesses 1 weaknesses 2 first_name  last_name
# 0      Passive       Chatty       Mona  Willimott  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  01/08/2019                 1         1                       1   Pass
#
#   course_interest    strengths 1 weaknesses 1 weaknesses 2 weaknesses 3  \
# 0     Engineering  Perfectionism    Impatient      Selfish  Indifferent
#
#   first_name last_name
# 0      Alvie  Bleackly  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  06/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  C#  Ruby strengths 1 strengths 2 weaknesses 1  \
# 0            Data       1   3     3     Empathy    Charisma         Slow
#
#   weaknesses 2 weaknesses 3 first_name   last_name
# 0      Anxious       Chatty       Drud  Tellenbrok  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  01/08/2019                 1         1                       1   Pass
#
#   course_interest  PHP strengths 1 weaknesses 1 first_name last_name
# 0        Business    1    Reliable  Indifferent       Deck  Itzchaki  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  14/08/2019                 1         0                       1   Fail
#
#   course_interest  Python  R  SPSS strengths 1 strengths 2  strengths 3  \
# 0            Data       3  2     1   Efficient     Empathy  Independent
#
#   weaknesses 1 weaknesses 2 first_name last_name
# 0   Indecisive      Chaotic    Charlie   Danelut  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  01/08/2019                 0         1                       1   Fail
#
#   course_interest  JavaScript    strengths 1 strengths 2 weaknesses 1  \
# 0            Data           5  Collaboration     Curious         Slow
#
#   weaknesses 2 first_name last_name
# 0    Sensitive       Wilt   Penritt  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  15/08/2019                 1         1                       1   Pass
#
#   course_interest  C#  Java  R  SPSS strengths 1 weaknesses 1 first_name  \
# 0     Engineering   2     4  1     6    Reliable  Overbearing     Stevie
#
#    last_name
# 0  Houliston  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  14/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  Java  R  SPSS  PHP  JavaScript  strengths 1  \
# 0        Business       3     5  2     4    1           1  Independent
#
#   strengths 2   weaknesses 1 weaknesses 2 weaknesses 3 first_name last_name
# 0   Ambitious  Perfectionist  Introverted   Indecisive    Fairlie   Cogzell  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  22/08/2019                 1         1                       1   Fail
#
#   course_interest  C#  Java  SPSS  JavaScript strengths 1 weaknesses 1  \
# 0        Business   4     6     1           3     Curious         Slow
#
#   first_name last_name
# 0     Beckie   Aveling  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  15/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  Java  Ruby  PHP strengths 1 strengths 2  \
# 0        Business       2     3     4    2    Rational  Innovative
#
#      strengths 3 weaknesses 1 weaknesses 2 first_name last_name
# 0  Collaboration    Impatient   Distracted        Axe    Mckall  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  27/08/2019                 1         0                       1   Fail
#
#   course_interest  Python  C++ strengths 1 strengths 2 weaknesses 1  \
# 0        Business       3    1     Curious  Passionate      Selfish
#
#   first_name last_name
# 0    Marcela      Pass  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  13/08/2019                 1         1                       1   Pass
#
#   course_interest  Java  Ruby  PHP strengths 1 strengths 2 strengths 3  \
# 0            Data     2     1    1    Rational  Innovative  Passionate
#
#   weaknesses 1 weaknesses 2 weaknesses 3 first_name last_name
# 0     Immature  Competitive  Indifferent    Sauncho    Aveson  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  15/08/2019                 0         1                       1   Fail
#
#   course_interest  Ruby  R  C++  JavaScript strengths 1 weaknesses 1  \
# 0     Engineering     6  1    2           2   Versatile   Distracted
#
#   weaknesses 2 first_name last_name
# 0         Slow     Shamus  Mccomish  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  22/08/2019                 1         1                       1   Pass
#
#   course_interest strengths 1  strengths 2   weaknesses 1     weaknesses 2  \
# 0        Business   Ambitious  Independent  Perfectionist  Procrastination
#
#   first_name last_name
# 0       Andy      Lown  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  14/08/2019                 1         1                       1   Pass
#
#   course_interest  Java strengths 1 weaknesses 1 first_name   last_name
# 0     Engineering     1   Efficient  Competitive       Arny  Coorington  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  15/08/2019                 0         1                       1   Fail
#
#   course_interest  Python  R  PHP  JavaScript strengths 1 strengths 2  \
# 0     Engineering       4  3    2           2    Creative  Passionate
#
#   strengths 3 weaknesses 1 first_name last_name
# 0    Reliable   Distracted   Devondra    Blabey  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  07/08/2019                 1         1                       1   Pass
#
#   course_interest  Java  Ruby      strengths 1   weaknesses 1 first_name  \
# 0     Engineering     1     2  Problem Solving  Perfectionist      Irita
#
#   last_name
# 0   Lyptrit  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  29/08/2019                 1         1                       1   Pass
#
#   course_interest  C#  R  SPSS  PHP  C++ strengths 1    strengths 2  \
# 0            Data   2  3     3    2    5  Consistent  Collaboration
#
#   weaknesses 1 first_name last_name
# 0     Stubborn        Jae  Rennolds  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  15/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  SPSS  JavaScript  strengths 1 strengths 2  \
# 0        Business       5     3           4  Independent  Passionate
#
#   weaknesses 1 first_name  last_name
# 0  Overbearing     Marion  Consadine  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  13/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  C++ strengths 1 weaknesses 1 weaknesses 2  \
# 0            Data       3    4  Passionate  Indifferent      Anxious
#
#   first_name  last_name
# 0    Leonore  Pettiford  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  07/08/2019                 1         1                       1   Pass
#
#   course_interest  SPSS  strengths 1 weaknesses 1 first_name last_name
# 0            Data     7  Competitive  Controlling     Edvard   Northen  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  07/08/2019                 1         0                       1   Fail
#
#   course_interest  C#  Java  Ruby  SPSS strengths 1 strengths 2 strengths 3  \
# 0        Business   6     5     5     6   Versatile  Consistent  Passionate
#
#   weaknesses 1 weaknesses 2 weaknesses 3 first_name last_name
# 0   Intolerant   Distracted    Impulsive     Oralla  Peasgood  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  13/08/2019                 1         0                       1   Fail
#
#   course_interest  Ruby  PHP  JavaScript strengths 1    strengths 2  \
# 0        Business     1    4           1     Curious  Perfectionism
#
#   strengths 3 weaknesses 1  weaknesses 2 first_name last_name
# 0  Determined      Selfish  Conventional         Ly     Ferro  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  29/08/2019                 1         1                       1   Fail
#
#   course_interest  Python  Java  Ruby  R  C++ strengths 1 strengths 2  \
# 0            Data       1     1     4  4    6   Courteous   Ambitious
#
#   strengths 3 weaknesses 1 weaknesses 2 first_name last_name
# 0   Versatile    Sensitive  Introverted    Lindsey   Gerwood  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  01/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  Java  strengths 1  strengths 2 strengths 3  \
# 0        Business       3     4  Independent  Competitive  Determined
#
#   weaknesses 1 weaknesses 2 first_name last_name
# 0     Immature      Chaotic     Gianna   Clevely  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  15/08/2019                 1         1                       1   Pass
#
#   course_interest  C#  Java strengths 1 strengths 2 strengths 3 weaknesses 1  \
# 0            Data   8     4    Reliable     Curious   Courteous    Impatient
#
#   first_name last_name
# 0     Celine     Doree  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  21/08/2019                 1         1                       1   Pass
#
#   course_interest  C#  Ruby  C++  JavaScript strengths 1 strengths 2  \
# 0            Data   2     1    2           1   Courteous  Determined
#
#   weaknesses 1 weaknesses 2  weaknesses 3 first_name last_name
# 0  Controlling   Intolerant  Conventional    Karlene   Hughill  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  14/08/2019                 1         1                       0   Fail
#
#   course_interest  Python  C#  Java  PHP  C++  strengths 1   weaknesses 1  \
# 0     Engineering       5   3     1    2    5  Independent  Perfectionist
#
#   weaknesses 2 first_name  last_name
# 0   Distracted      Sayre  Webberley  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  15/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  R  PHP strengths 1    strengths 2 strengths 3  \
# 0            Data       1  3    3    Charisma  Collaboration   Listening
#
#   weaknesses 1 first_name last_name
# 0   Indecisive    Phyllys    Baelde  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  20/08/2019                 1         0                       1   Fail
#
#   course_interest  Python  Java  C++ strengths 1 strengths 2 weaknesses 1  \
# 0        Business       4     2    1    Rational  Passionate     Stubborn
#
#   weaknesses 2 first_name last_name
# 0    Impulsive    Samuele     Whear  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  27/08/2019                 1         1                       1   Pass
#
#   course_interest  Java  SPSS strengths 1 strengths 2 strengths 3  \
# 0        Business     1     1     Curious     Empathy    Creative
#
#   weaknesses 1 weaknesses 2 weaknesses 3 first_name last_name
# 0      Anxious         Slow  Competitive     Darcey    Mordin  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  13/08/2019                 1         1                       1   Pass
#
#   course_interest  Java  Ruby strengths 1    strengths 2 strengths 3  \
# 0     Engineering     2     5     Curious  Perfectionism  Determined
#
#   weaknesses 1 weaknesses 2 weaknesses 3 first_name  last_name
# 0    Impatient      Passive   Intolerant   Pamelina  Itzkovsky  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  13/08/2019                 1         1                       1   Pass
#
#   course_interest  Java  Ruby strengths 1    strengths 2 strengths 3  \
# 0     Engineering     2     5     Curious  Perfectionism  Determined
#
#   weaknesses 1 weaknesses 2 weaknesses 3 first_name  last_name
# 0    Impatient      Passive   Intolerant   Pamelina  Itzkovsky  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  21/08/2019                 1         0                       1   Fail
#
#   course_interest  Ruby  C++  JavaScript strengths 1 weaknesses 1  \
# 0     Engineering     4    3           2   Ambitious       Chatty
#
#   weaknesses 2 weaknesses 3 first_name  last_name
# 0   Distracted         Slow     Laurel  Gillogley  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  28/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  SPSS  JavaScript strengths 1  weaknesses 1  \
# 0     Engineering       1     2           3  Consistent  Conventional
#
#   weaknesses 2 first_name last_name
# 0   Intolerant     Quinta   Cowdray  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  15/08/2019                 1         1                       1   Fail
#
#   course_interest  SPSS  C++    strengths 1 weaknesses 1 weaknesses 2  \
# 0     Engineering     5    4  Perfectionism         Slow    Impulsive
#
#   first_name last_name
# 0     Cecile     Lates  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  14/08/2019                 1         1                       1   Pass
#
#   course_interest  C#  PHP  C++ strengths 1 strengths 2 strengths 3  \
# 0     Engineering   1    2    1    Altruism     Empathy  Innovative
#
#   weaknesses 1 first_name last_name
# 0   Distracted     Seumas   Lemonby  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  13/08/2019                 1         1                       1   Pass
#
#   course_interest  Java  Ruby  R strengths 1   strengths 2 strengths 3  \
# 0            Data     7     2  2    Rational  Organisation  Consistent
#
#       weaknesses 1 first_name last_name
# 0  Procrastination       Gale  Quartley  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  22/08/2019                 0         1                       1   Fail
#
#   course_interest  C# strengths 1 weaknesses 1 weaknesses 2 first_name  \
# 0     Engineering   1    Charisma  Introverted    Sensitive     Dorrie
#
#   last_name
# 0   Srutton  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  21/08/2019                 0         0                       1   Fail
#
#   course_interest  Java  SPSS  JavaScript      strengths 1 weaknesses 1  \
# 0            Data     1     1           4  Problem Solving    Impulsive
#
#   weaknesses 2 first_name  last_name
# 0     Stubborn      Benny  Tichelaar  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  15/08/2019                 1         1                       1   Pass
#
#   course_interest  C#  SPSS  JavaScript strengths 1 weaknesses 1 weaknesses 2  \
# 0        Business   2     4           3   Versatile  Introverted      Chaotic
#
#   first_name last_name
# 0      Avrit    Gawith  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  22/08/2019                 1         1                       1   Fail
#
#   course_interest  SPSS  PHP  C++ strengths 1 weaknesses 1 weaknesses 2  \
# 0            Data     2    5    8  Consistent     Stubborn      Anxious
#
#   weaknesses 3 first_name last_name
# 0  Competitive      Berti   Dennehy  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  14/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  Java strengths 1 strengths 2 strengths 3  \
# 0     Engineering       6     3   Composure    Charisma    Rational
#
#   weaknesses 1 weaknesses 2 first_name last_name
# 0  Indifferent    Sensitive     Rockey   Robarts  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  21/08/2019                 1         1                       0   Fail
#
#   course_interest  C#  Ruby  PHP strengths 1 weaknesses 1 weaknesses 2  \
# 0        Business   2     2    1   Efficient      Anxious       Chatty
#
#   first_name last_name
# 0     Eloisa     Ewert  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  21/08/2019                 1         1                       1   Pass
#
#   course_interest  SPSS  PHP strengths 1 strengths 2 strengths 3 weaknesses 1  \
# 0            Data     3    2  Passionate    Reliable    Altruism       Chatty
#
#   weaknesses 2 weaknesses 3 first_name last_name
# 0     Critical      Passive   Mireille     Risom  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  22/08/2019                 1         1                       1   Pass
#
#   course_interest  Ruby  R  SPSS  JavaScript strengths 1    strengths 2  \
# 0     Engineering     1  1     1           3   Efficient  Perfectionism
#
#   weaknesses 1 first_name last_name
# 0  Controlling      Sharl   Daggett  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  15/08/2019                 1         1                       1   Fail
#
#   course_interest  Java  R  C++  JavaScript strengths 1 strengths 2  \
# 0        Business     2  5    2           3     Empathy     Curious
#
#   weaknesses 1 weaknesses 2 first_name last_name
# 0      Chaotic     Stubborn    Nikolos    Yashin  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  14/08/2019                 1         1                       1   Fail
#
#   course_interest  SPSS  PHP  C++ strengths 1 strengths 2   strengths 3  \
# 0     Engineering     3    1    1   Courteous     Curious  Organisation
#
#   weaknesses 1     weaknesses 2 first_name last_name
# 0     Stubborn  Procrastination      Shela    Mccall  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  14/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  Ruby  SPSS  C++   strengths 1 strengths 2  \
# 0        Business       4     2     3    6  Organisation   Courteous
#
#     weaknesses 1 first_name  last_name
# 0  Perfectionist     Sonnie  Malenfant  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  20/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  Ruby  C++  JavaScript strengths 1 strengths 2  \
# 0        Business       7     7    2           1    Rational    Charisma
#
#   weaknesses 1 weaknesses 2 weaknesses 3 first_name last_name
# 0       Chatty   Distracted    Sensitive     Mahmud  Molineux  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  29/08/2019                 1         1                       0   Fail
#
#   course_interest  Python  C#  R  SPSS    strengths 1 strengths 2  \
# 0            Data       2   1  5     1  Perfectionism   Ambitious
#
#     weaknesses 1 weaknesses 2   weaknesses 3 first_name  last_name
# 0  Undisciplined   Intolerant  Perfectionist      Dylan  Llewellen  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  01/08/2019                 1         1                       0   Fail
#
#   course_interest  C#  Java  Ruby  R strengths 1 strengths 2 strengths 3  \
# 0            Data   2     3     7  1    Charisma    Creative     Curious
#
#   weaknesses 1     weaknesses 2 weaknesses 3 first_name last_name
# 0   Intolerant  Procrastination     Immature       Yvor    Phalip  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  29/08/2019                 1         1                       1   Pass
#
#   course_interest  PHP  strengths 1 strengths 2 weaknesses 1 first_name  \
# 0        Business    3  Competitive   Versatile     Immature      Berry
#
#   last_name
# 0     Freed  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  01/08/2019                 1         0                       1   Fail
#
#   course_interest  C#  Ruby  R  SPSS  PHP        strengths 1 weaknesses 1  \
# 0        Business   5     4  5     7    1  Critical Thinking  Overbearing
#
#   weaknesses 2 first_name last_name
# 0   Indecisive   Marielle   Knivett  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  15/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  Java  C++ strengths 1 strengths 2 strengths 3  \
# 0            Data       1     3    1  Passionate    Altruism   Courteous
#
#   weaknesses 1     weaknesses 2 first_name last_name
# 0  Overbearing  Procrastination   Emmanuel   Deniske  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  07/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  C#  R  SPSS  C++ strengths 1 weaknesses 1  \
# 0            Data       7   1  2     3    6     Curious  Controlling
#
#   weaknesses 2 weaknesses 3 first_name last_name
# 0    Sensitive   Distracted       Kerr    Coucha  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  21/08/2019                 1         1                       1   Pass
#
#   course_interest  Java  R  PHP  JavaScript strengths 1 strengths 2  \
# 0            Data     2  3    1           6   Versatile    Creative
#
#   weaknesses 1 weaknesses 2 first_name last_name
# 0       Chatty    Sensitive      Dulci  Mcgrayle  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  21/08/2019                 0         1                       1   Fail
#
#   course_interest  Python  C#  Ruby  C++        strengths 1 weaknesses 1  \
# 0     Engineering       3   3     4    1  Critical Thinking     Stubborn
#
#   first_name last_name
# 0    Shandee  Blaschke  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  14/08/2019                 1         1                       0   Fail
#
#   course_interest  Java strengths 1   strengths 2     weaknesses 1  \
# 0     Engineering     4   Composure  Organisation  Procrastination
#
#   weaknesses 2  weaknesses 3 first_name last_name
# 0    Impatient  Conventional       Paul  Chislett  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  01/08/2019                 0         1                       1   Fail
#
#   course_interest  C# strengths 1 weaknesses 1 weaknesses 2  weaknesses 3  \
# 0     Engineering   1   Ambitious  Indifferent     Critical  Conventional
#
#   first_name last_name
# 0     Florri  Loughton  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  08/08/2019                 0         1                       1   Fail
#
#   course_interest  C#  R  JavaScript    strengths 1 strengths 2 weaknesses 1  \
# 0            Data   3  1           3  Perfectionism   Courteous  Indifferent
#
#   first_name last_name
# 0      Hildy    Landre  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  06/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  Java  Ruby  SPSS  PHP strengths 1    strengths 2  \
# 0            Data       4     6     2     3    4    Altruism  Collaboration
#
#   weaknesses 1 first_name last_name
# 0    Impulsive      Berny    Botler  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  13/08/2019                 1         1                       1   Fail
#
#   course_interest  SPSS  C++    strengths 1    strengths 2 strengths 3  \
# 0     Engineering     4    6  Perfectionism  Collaboration     Patient
#
#   weaknesses 1 first_name last_name
# 0  Indifferent     Merell   Tremmil  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  21/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  Java  Ruby  C++  JavaScript strengths 1  \
# 0        Business       4     2     5    6           2  Passionate
#
#   strengths 2 weaknesses 1 first_name last_name
# 0   Versatile  Competitive     Ileana   Chewter  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  13/08/2019                 0         1                       1   Fail
#
#   course_interest  Python  C#  R strengths 1     weaknesses 1 first_name  \
# 0     Engineering       4   1  3   Listening  Procrastination     Ilario
#
#   last_name
# 0    Yeates  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  06/08/2019                 1         0                       1   Fail
#
#   course_interest  C#  R  JavaScript strengths 1 weaknesses 1 first_name  \
# 0        Business   4  2           2     Patient   Indecisive     Winnie
#
#   last_name
# 0  Lewerenz  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  20/08/2019                 0         1                       1   Fail
#
#   course_interest  Java  C++  JavaScript strengths 1 strengths 2 weaknesses 1  \
# 0            Data     3    3           2  Consistent    Creative       Chatty
#
#   weaknesses 2 first_name last_name
# 0    Impulsive    Garwood   Strowan  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  08/08/2019                 1         1                       1   Pass
#
#   course_interest  Java  Ruby  R  SPSS  PHP  C++ strengths 1 weaknesses 1  \
# 0            Data     3     2  2     4    7    1  Determined    Sensitive
#
#   weaknesses 2 first_name  last_name
# 0      Passive       Herb  Mcilmorie  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  01/08/2019                 1         1                       1   Pass
#
#   course_interest  Java  R  C++  JavaScript strengths 1 strengths 2  \
# 0            Data     6  4    3           3    Charisma    Altruism
#
#      strengths 3 weaknesses 1 weaknesses 2 weaknesses 3 first_name last_name
# 0  Perfectionism  Competitive  Indifferent      Chaotic    Ingunna      Adin  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  29/08/2019                 1         0                       1   Fail
#
#   course_interest  C#  Ruby  SPSS  C++  JavaScript strengths 1 weaknesses 1  \
# 0            Data   2     4     3    1           5    Altruism    Impulsive
#
#   first_name last_name
# 0    Frazier   Bayston  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  13/08/2019                 1         1                       1   Pass
#
#   course_interest  C#  Ruby  R  PHP  C++  JavaScript strengths 1 strengths 2  \
# 0     Engineering   1     2  6    1    5           3    Rational  Determined
#
#     strengths 3 weaknesses 1 weaknesses 2 weaknesses 3 first_name last_name
# 0  Organisation         Slow  Controlling      Anxious     Hewett   Lamputt  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  22/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  SPSS strengths 1 strengths 2 weaknesses 1  \
# 0            Data       6     3   Courteous    Rational      Selfish
#
#   weaknesses 2 first_name last_name
# 0    Impatient     Rodger  Bendelow  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  14/08/2019                 1         1                       1   Fail
#
#   course_interest  Python  Ruby  strengths 1      strengths 2 weaknesses 1  \
# 0        Business       2     4  Independent  Problem Solving     Critical
#
#   weaknesses 2 first_name last_name
# 0   Indecisive     Archer    Hobben  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  22/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  Java  SPSS  C++  JavaScript strengths 1  \
# 0     Engineering       1     1     2    4           1   Listening
#
#    strengths 2   strengths 3 weaknesses 1 first_name  last_name
# 0  Independent  Organisation      Selfish   Stephani  Prettyman  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  20/08/2019                 1         1                       1   Pass
#
#   course_interest  C#  Ruby  SPSS  PHP  JavaScript  strengths 1 strengths 2  \
# 0     Engineering   1     5     2    1           2  Competitive    Charisma
#
#   weaknesses 1 weaknesses 2 weaknesses 3 first_name last_name
# 0         Slow  Indifferent      Selfish       Pepi      Bome  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  06/08/2019                 1         1                       0   Fail
#
#   course_interest  C++ strengths 1 weaknesses 1  weaknesses 2   weaknesses 3  \
# 0            Data    6     Empathy  Introverted  Conventional  Undisciplined
#
#   first_name last_name
# 0     Loella    Lonnon  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  08/08/2019                 1         1                       1   Pass
#
#   course_interest  SPSS  PHP strengths 1  weaknesses 1 weaknesses 2  \
# 0        Business     3    2    Altruism  Conventional  Introverted
#
#   first_name last_name
# 0     Darrin   Stoffel  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  14/08/2019                 1         1                       0   Fail
#
#   course_interest  Python  C#  Java  SPSS  JavaScript      strengths 1  \
# 0     Engineering       2   2     3     2           3  Problem Solving
#
#   weaknesses 1 first_name last_name
# 0     Stubborn    Mitchel     Bates  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  08/08/2019                 1         1                       1   Pass
#
#   course_interest  C#  Java  PHP  JavaScript strengths 1 strengths 2  \
# 0        Business   2     2    2           4    Charisma  Passionate
#
#   strengths 3 weaknesses 1 weaknesses 2 weaknesses 3 first_name last_name
# 0    Creative         Slow   Intolerant    Sensitive      Miles     Water  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  28/08/2019                 1         1                       1   Fail
#
#   course_interest  Python  C#  SPSS    strengths 1 strengths 2 strengths 3  \
# 0     Engineering       2   3     6  Perfectionism   Efficient   Listening
#
#   weaknesses 1 weaknesses 2   weaknesses 3 first_name last_name
# 0   Indecisive  Indifferent  Undisciplined      Fanni   Polhill  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  22/08/2019                 0         1                       1   Fail
#
#   course_interest  Ruby  PHP strengths 1 strengths 2 strengths 3 weaknesses 1  \
# 0        Business     3    2    Reliable     Patient    Rational      Selfish
#
#   weaknesses 2 first_name last_name
# 0       Chatty   Genvieve     Arnke  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  28/08/2019                 1         1                       1   Pass
#
#   course_interest  C#  Java  R strengths 1  strengths 2 strengths 3  \
# 0        Business   3     4  4    Altruism  Competitive    Charisma
#
#   weaknesses 1 first_name last_name
# 0  Indifferent     Alicia    Hruska  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  15/08/2019                 1         1                       1   Pass
#
#   course_interest  Ruby  R  SPSS strengths 1 weaknesses 1 first_name last_name
# 0            Data     6  3     4   Listening  Introverted      Mella     Aubin  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  06/08/2019                 0         1                       1   Fail
#
#   course_interest  C#  Java  R    strengths 1 strengths 2 strengths 3  \
# 0     Engineering   1     2  2  Perfectionism   Listening   Ambitious
#
#   weaknesses 1 weaknesses 2 first_name  last_name
# 0      Anxious  Indifferent     George  Huckstepp  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  29/08/2019                 1         1                       0   Fail
#
#   course_interest  Python  C#      strengths 1 weaknesses 1 first_name  \
# 0        Business       1   4  Problem Solving       Chatty     Joelie
#
#   last_name
# 0    Elfitt  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  27/08/2019                 1         0                       1   Fail
#
#   course_interest  Ruby  JavaScript strengths 1 strengths 2 weaknesses 1  \
# 0     Engineering     3           1   Composure   Versatile    Impatient
#
#   weaknesses 2 weaknesses 3 first_name last_name
# 0         Slow     Critical       Omar   Rodrigo  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  15/08/2019                 1         1                       1   Fail
#
#   course_interest  Python  C#  Ruby  R  SPSS  PHP  JavaScript strengths 1  \
# 0        Business       3   3     2  7     1    2           1   Ambitious
#
#   strengths 2 strengths 3 weaknesses 1 weaknesses 2 first_name last_name
# 0    Reliable  Determined    Sensitive  Indifferent        Cal    Loache  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  07/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  Ruby  R strengths 1 weaknesses 1 weaknesses 2  \
# 0     Engineering       4     3  1    Rational     Stubborn  Indifferent
#
#   first_name last_name
# 0      Tully   Mcdoual  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  22/08/2019                 1         1                       1   Pass
#
#   course_interest  Java  R  SPSS  PHP strengths 1   weaknesses 1  \
# 0            Data     4  3     3    3   Listening  Perfectionist
#
#    weaknesses 2 first_name  last_name
# 0  Conventional      Molli  Brayfield  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  01/08/2019                 1         1                       1   Pass
#
#   course_interest  Python  R      strengths 1 strengths 2 weaknesses 1  \
# 0            Data       7  1  Problem Solving   Efficient     Stubborn
#
#   weaknesses 2   weaknesses 3 first_name last_name
# 0   Indecisive  Undisciplined     Janaya   Mawford  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  29/08/2019                 0         1                       1   Fail
#
#   course_interest  Java  R  strengths 1    strengths 2 weaknesses 1  \
# 0            Data     1  1  Independent  Perfectionism     Immature
#
#   first_name last_name
# 0    Lazarus     Hooke  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  08/08/2019                 1         1                       1   Pass
#
#   course_interest  JavaScript strengths 1 weaknesses 1  weaknesses 2  \
# 0            Data           1   Listening   Intolerant  Conventional
#
#     weaknesses 3 first_name   last_name
# 0  Undisciplined     Sidney  Le Batteur  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  20/08/2019                 1         1                       1   Pass
#
#   course_interest  Java  Ruby  PHP  JavaScript      strengths 1 strengths 2  \
# 0            Data     3     4    1           4  Problem Solving    Altruism
#
#   strengths 3 weaknesses 1     weaknesses 2   weaknesses 3 first_name  \
# 0     Patient   Indecisive  Procrastination  Undisciplined  Maryellen
#
#   last_name
# 0   Vasovic  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  29/08/2019                 1         1                       1   Pass
#
#   course_interest  C#  Ruby  JavaScript strengths 1 weaknesses 1 first_name  \
# 0     Engineering   1     3           3   Courteous  Controlling     Winona
#
#     last_name
# 0  Rubinowitz  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  14/08/2019                 1         1                       1   Fail
#
#   course_interest  C#  Ruby  R  SPSS  PHP  C++ strengths 1 strengths 2  \
# 0     Engineering   1     2  4     4    1    3  Consistent  Innovative
#
#   weaknesses 1 weaknesses 2 weaknesses 3 first_name last_name
# 0  Indifferent   Indecisive  Controlling        Dur      Plom  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  15/08/2019                 1         1                       1   Pass
#
#   course_interest  Java  SPSS  JavaScript strengths 1        strengths 2  \
# 0     Engineering     1     3           1   Efficient  Critical Thinking
#
#   strengths 3 weaknesses 1  weaknesses 2 first_name last_name
# 0    Creative      Chaotic  Conventional     Gisela   Aisbett  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  29/08/2019                 1         0                       0   Fail
#
# ...
# 0  11/04/2019                 1         1                       0   Fail
#
#   course_interest  C#  Ruby  SPSS  JavaScript strengths 1 strengths 2  \
# 0        Business   2     4     1           4     Empathy  Determined
#
#   weaknesses 1 weaknesses 2 first_name last_name
# 0    Impulsive    Sensitive     Amalea    Tysack  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  10/04/2019                 1         1                       1   Pass
#
#   course_interest  Java  Ruby strengths 1 strengths 2 strengths 3  \
# 0            Data     2     2   Efficient     Patient   Listening
#
#   weaknesses 1 weaknesses 2 weaknesses 3 first_name last_name
# 0   Intolerant    Impulsive     Critical     Mickey   Lamport  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  09/04/2019                 1         0                       0   Fail
#
#   course_interest  Python  R  SPSS  PHP strengths 1 strengths 2 strengths 3  \
# 0     Engineering       1  1     7    1   Composure    Altruism    Rational
#
#   weaknesses 1 weaknesses 2 first_name last_name
# 0    Sensitive   Distracted       Bart  Bouttell  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  18/04/2019                 1         1                       1   Pass
#
#   course_interest  C#  SPSS    strengths 1  strengths 2   weaknesses 1  \
# 0        Business   5     3  Collaboration  Independent  Perfectionist
#
#    weaknesses 2 first_name last_name
# 0  Conventional   Thatcher  Frankish  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  10/04/2019                 1         1                       0   Fail
#
#   course_interest  Python  R  SPSS  strengths 1 strengths 2 weaknesses 1  \
# 0            Data       3  5     5  Independent    Creative  Controlling
#
#   first_name last_name
# 0      Myrna  Bonafant  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  17/04/2019                 1         1                       1   Pass
#
#   course_interest  Python  R strengths 1 strengths 2 strengths 3 weaknesses 1  \
# 0        Business       4  5  Consistent     Patient    Reliable  Introverted
#
#   weaknesses 2 weaknesses 3 first_name last_name
# 0  Competitive         Slow      Biddy     Rapps  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  25/04/2019                 1         1                       1   Fail
#
#   course_interest  Python  Java  Ruby  SPSS  PHP strengths 1 weaknesses 1  \
# 0     Engineering       7     3     4     1    3    Altruism  Controlling
#
#   weaknesses 2 weaknesses 3 first_name last_name
# 0  Indifferent  Competitive      Jarib   Rayhill  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  09/04/2019                 1         1                       1   Pass
#
#   course_interest  Python  R strengths 1 weaknesses 1 first_name last_name
# 0     Engineering       1  2   Versatile     Critical       Lise   Wildman  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  18/04/2019                 1         0                       1   Fail
#
#   course_interest  Python  Java  R  JavaScript strengths 1 strengths 2  \
# 0            Data       5     4  1           3    Altruism   Courteous
#
#    weaknesses 1 weaknesses 2 weaknesses 3 first_name last_name
# 0  Conventional       Chatty      Passive   Joycelin  Doerffer  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  04/04/2019                 1         1                       1   Pass
#
#   course_interest  Python  Ruby  SPSS    strengths 1 strengths 2 weaknesses 1  \
# 0            Data       5     2     4  Collaboration    Creative       Chatty
#
#     weaknesses 2 first_name last_name
# 0  Perfectionist  Remington  Hensmans  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  11/04/2019                 1         1                       1   Pass
#
#   course_interest  C#  Java  SPSS  PHP strengths 1 weaknesses 1 weaknesses 2  \
# 0     Engineering   5     3     6    2   Versatile      Passive         Slow
#
#   first_name last_name
# 0    Auberta   Ruddick  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  16/04/2019                 1         1                       1   Pass
#
#   course_interest  Python  Java strengths 1 strengths 2 strengths 3  \
# 0            Data       4     5    Reliable    Altruism     Curious
#
#   weaknesses 1 first_name last_name
# 0      Anxious     Louise     Dowse  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  16/04/2019                 1         1                       1   Pass
#
#   course_interest  C#  Ruby  strengths 1 weaknesses 1   weaknesses 2  \
# 0     Engineering   1     2  Competitive   Intolerant  Perfectionist
#
#   weaknesses 3 first_name last_name
# 0   Distracted     Yelena  Kelleway  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  10/04/2019                 1         1                       0   Fail
#
#   course_interest  C#  SPSS  PHP  C++  JavaScript   strengths 1 strengths 2  \
# 0        Business   1     2    4    2           1  Organisation    Charisma
#
#   strengths 3 weaknesses 1   weaknesses 2 weaknesses 3 first_name last_name
# 0     Patient   Indecisive  Perfectionist    Impatient       Luke      Able  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  25/04/2019                 1         1                       1   Pass
#
#   course_interest  C#  Java  R  JavaScript strengths 1 weaknesses 1  \
# 0        Business   1     2  3           5     Empathy    Impulsive
#
#   first_name last_name
# 0        Ave    Waudby  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  04/04/2019                 1         1                       1   Pass
#
#   course_interest  R  SPSS  C++ strengths 1        strengths 2 strengths 3  \
# 0     Engineering  1     1    3    Reliable  Critical Thinking    Charisma
#
#   weaknesses 1 weaknesses 2 first_name last_name
# 0    Impulsive   Intolerant     Pearce   Maxwale  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  16/04/2019                 1         1                       0   Fail
#
#   course_interest  C#  SPSS  JavaScript strengths 1 strengths 2 weaknesses 1  \
# 0            Data   2     3           1    Reliable   Listening  Indifferent
#
#   weaknesses 2 first_name   last_name
# 0   Intolerant  Isabelita  Alexandrou  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  11/04/2019                 1         1                       1   Pass
#
#   course_interest  C#  Ruby  SPSS  C++ strengths 1    strengths 2 strengths 3  \
# 0            Data   5     2     6    4     Curious  Perfectionism   Ambitious
#
#   weaknesses 1 first_name last_name
# 0  Overbearing    Kathlin   Gibling  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  04/04/2019                 1         1                       1   Fail
#
#   course_interest  C#  Java  Ruby  C++  JavaScript strengths 1 strengths 2  \
# 0            Data   1     2     3    5           4     Patient   Courteous
#
#    strengths 3 weaknesses 1 weaknesses 2 first_name last_name
# 0  Competitive   Intolerant    Sensitive       Thea    Persey  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  03/04/2019                 1         1                       1   Pass
#
#   course_interest  Ruby  R  JavaScript strengths 1 strengths 2 weaknesses 1  \
# 0        Business     3  2           5  Passionate  Determined  Controlling
#
#   weaknesses 2 first_name last_name
# 0  Introverted    Latisha      Ibel  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  02/04/2019                 1         1                       1   Pass
#
#   course_interest  Python  C#  Ruby  SPSS  PHP strengths 1 strengths 2  \
# 0            Data       4   2     5     2    1   Composure   Ambitious
#
#   strengths 3 weaknesses 1 weaknesses 2  weaknesses 3 first_name last_name
# 0    Charisma     Critical      Passive  Conventional      Howie     Haith  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  17/04/2019                 1         1                       1   Pass
#
#   course_interest  Python  Ruby strengths 1      strengths 2  strengths 3  \
# 0     Engineering       4     1    Charisma  Problem Solving  Competitive
#
#   weaknesses 1 weaknesses 2 first_name last_name
# 0   Intolerant  Controlling       Beth     Tiner  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  02/04/2019                 1         1                       1   Pass
#
#   course_interest  C#  R  PHP  C++  JavaScript        strengths 1  \
# 0        Business   4  5    3    2           3  Critical Thinking
#
#      strengths 2   weaknesses 1 weaknesses 2 first_name last_name
# 0  Perfectionism  Perfectionist   Distracted   Josselyn    Kaindl  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  25/04/2019                 1         1                       1   Fail
#
#   course_interest  C++ strengths 1 weaknesses 1 weaknesses 2 first_name  \
# 0        Business    3     Empathy    Impatient       Chatty     Fidela
#
#     last_name
# 0  Dallywater  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  04/04/2019                 1         0                       0   Fail
#
#   course_interest  Python  C#  Ruby  R  SPSS  JavaScript  strengths 1  \
# 0        Business       3   2     8  5     4           4  Independent
#
#   strengths 2 strengths 3   weaknesses 1 first_name last_name
# 0    Altruism     Patient  Undisciplined      Berry      Codd  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  09/04/2019                 1         1                       1   Pass
#
#   course_interest  C#  R  SPSS  C++        strengths 1 strengths 2  \
# 0        Business   2  1     2    3  Critical Thinking    Reliable
#
#    strengths 3 weaknesses 1 weaknesses 2   weaknesses 3 first_name last_name
# 0  Competitive     Critical  Introverted  Perfectionist   Kariotta   Barense  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  16/04/2019                 1         1                       1   Pass
#
#   course_interest  Python  Ruby strengths 1        strengths 2 strengths 3  \
# 0            Data       3     2   Listening  Critical Thinking    Creative
#
#   weaknesses 1 weaknesses 2 weaknesses 3 first_name last_name
# 0    Impulsive      Selfish   Distracted     Dickie   Kearton  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  24/04/2019                 1         1                       1   Pass
#
#   course_interest  Java  Ruby strengths 1 strengths 2 strengths 3  \
# 0            Data     3     1   Efficient     Patient  Consistent
#
#   weaknesses 1 weaknesses 2 first_name last_name
# 0    Sensitive      Chaotic   Garnette  Zanussii  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  30/04/2019                 1         1                       1   Fail
#
#   course_interest  C#  R  SPSS  JavaScript strengths 1 weaknesses 1  \
# 0        Business   1  1     6           5    Reliable  Overbearing
#
#   weaknesses 2 first_name last_name
# 0      Anxious       Knox    Mcgraw  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  11/04/2019                 1         1                       0   Fail
#
#   course_interest  C#  SPSS  PHP  JavaScript strengths 1    strengths 2  \
# 0        Business   3     2    5           4     Empathy  Collaboration
#
#   weaknesses 1 weaknesses 2 first_name   last_name
# 0      Chaotic  Indifferent      Parke  Coulthurst  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  18/04/2019                 1         1                       1   Pass
#
#   course_interest  C#  Ruby  R  JavaScript strengths 1        strengths 2  \
# 0     Engineering   2     4  5           5   Ambitious  Critical Thinking
#
#   strengths 3 weaknesses 1 first_name  last_name
# 0  Passionate      Anxious    Wendell  Thomassen  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  25/04/2019                 1         1                       0   Fail
#
#   course_interest  Python  C#  SPSS  C++ strengths 1      strengths 2  \
# 0     Engineering       5   3     2    4   Efficient  Problem Solving
#
#   strengths 3 weaknesses 1 first_name last_name
# 0   Versatile      Passive      Ertha     Nudds  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  17/04/2019                 1         1                       1   Pass
#
#   course_interest  Python  Java  R  SPSS  JavaScript   strengths 1  \
# 0     Engineering       3     1  2     4           4  Organisation
#
#   strengths 2  weaknesses 1   weaknesses 2 first_name last_name
# 0  Determined  Conventional  Perfectionist      Kayle    Ferenc  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  17/04/2019                 1         1                       1   Fail
#
#   course_interest  Python  C#  PHP  C++ strengths 1  strengths 2 weaknesses 1  \
# 0     Engineering       6   1    4    6    Creative  Competitive  Introverted
#
#   weaknesses 2     weaknesses 3 first_name last_name
# 0      Chaotic  Procrastination    Gonzalo  Danniell  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  30/04/2019                 1         1                       0   Fail
#
#   course_interest  Python  Java  R  SPSS  PHP strengths 1 strengths 2  \
# 0     Engineering       3     5  2     3    1   Composure   Courteous
#
#      strengths 3 weaknesses 1 first_name last_name
# 0  Perfectionism         Slow    Lurleen   Cestard  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  04/04/2019                 1         0                       1   Fail
#
#   course_interest  C#  Java  R  SPSS strengths 1 weaknesses 1 weaknesses 2  \
# 0        Business   2     6  1     4   Versatile  Indifferent   Intolerant
#
#   weaknesses 3 first_name  last_name
# 0  Introverted      Jacky  Reilingen  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  10/04/2019                 1         1                       1   Pass
#
#   course_interest  C#  Java  Ruby  PHP   strengths 1  strengths 2 strengths 3  \
# 0     Engineering   4     4     4    1  Organisation  Independent  Determined
#
#   weaknesses 1 weaknesses 2 weaknesses 3 first_name last_name
# 0    Sensitive  Overbearing    Impatient    Phillis   Lyfield  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  16/04/2019                 1         1                       1   Pass
#
#   course_interest  R  C++  JavaScript      strengths 1 weaknesses 1  \
# 0     Engineering  2    1           4  Problem Solving     Critical
#
#   first_name last_name
# 0      Celle    Barlas  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  11/04/2019                 1         1                       1   Pass
#
#   course_interest  Ruby strengths 1    strengths 2      strengths 3  \
# 0            Data     3    Reliable  Perfectionism  Problem Solving
#
#   weaknesses 1 first_name last_name
# 0     Stubborn      Scott      Duny  ,          date  self_development  geo_flex  financial_support_self result  \
# 0  25/04/2019                 1         1                       0   Fail
#
#   course_interest  Python  C#  Java  C++  strengths 1 weaknesses 1  \
# 0     Engineering       2   3     3    4  Independent  Controlling
#
#   weaknesses 2 first_name   last_name
# 0     Stubborn     Boycey  Matushenko  ]
